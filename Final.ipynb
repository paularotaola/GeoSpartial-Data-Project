# %% [markdown]
# ## Proyecto

# %%
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import src.limpieza as lp
import src.requests as req
from pymongo import MongoClient
import json
import numpy as np
import geopandas
from folium import Map, Marker, Icon, FeatureGroup, LayerControl, Choropleth
import matplotlib.pyplot as plt
import os
import requests

# %% [markdown]
# ### Query a MongoDb - Crunchbase Dataset

# %%
#conecto con MongoDb y hago un query para sacar las empresas del país que nos interesa
mongodbURL = f"mongodb://localhost/datamad0620"
client = MongoClient(mongodbURL, connectTimeoutMS=2000, serverSelectionTimeoutMS=2000)
db = client.get_database("datamad0620")

# %%
result= lp.companiesMongo("SGP")
pd.DataFrame(result).sort_values(by="total_money_raised", ascending=False).head(5)
# Out:
#                          _id        name category_code  founded_year  \
# 40  52cdef7f4bab8bd67529bd7e       YOOSE        mobile        2008.0
# 31  52cdef7e4bab8bd67529adab      Nexway     ecommerce        2002.0
# 4   52cdef7c4bab8bd67529815a  Skyscanner           web        2001.0
# 5   52cdef7c4bab8bd67529869f       eYeka      software        2006.0
# 32  52cdef7e4bab8bd67529b07c     Majitek      software           NaN
#
#    total_money_raised                                            offices
# 40               €25k  [{'description': 'Germany', 'address1': 'Fried...
# 31               €14M  [{'description': 'Nexway HQ', 'address1': '1 b...
# 4               £2.5M  [{'description': 'Skyscanner Ltd', 'address1':...
# 5              $9.34M  [{'description': 'HQ', 'address1': '79 rue la ...
# 32              $7.5M  [{'description': '', 'address1': 'SGX Centre 2...

# %% [markdown]
# ### Limpieza de datos

# %%
#Sacamos toda la info de la columna "offices" que contiene listas con direcciones de todas las oficinas
#concatenamos ambos dataframes y renombramos la columna de "id"
#Volvemos a filtrar por país para eliminar las oficinas que no nos interesan


data = lp.limipiezaData(result, "SGP")
data.head(5)
# Out:
#          name                company_id         description  \
# 0  Alstrasoft  52cdef7c4bab8bd675297e8f                None
# 1       mig33  52cdef7c4bab8bd675297fda  mig33 Headquarters
# 2      tyntec  52cdef7c4bab8bd675298060           Singapore
# 3       OANDA  52cdef7c4bab8bd67529810e  OANDA Asia Pacific
# 4  Skyscanner  52cdef7c4bab8bd67529815a      Skyscanner Ltd
#
#                                         address1                address2  \
# 0  14 Robinson Road #13-00 Far East Finance Buil               Suite 100
# 1                          111 North Bridge Road  Peninsula Plaza #26-01
# 2                              51 Goldhill Plaza               #11-01/02
# 3                                50 Collyer Quay     #04-03 OUE Bayfront
# 4                                   OFC Level 40         10 Collyer Quay
#
#   zip_code       city state_code country_code   latitude   longitude
# 0   048545  Singapore       None          SGP        NaN         NaN
# 1   179098  Singapore       None          SGP  37.580304 -122.343679
# 2   308900  Singapore       None          SGP        NaN         NaN
# 3   049321  Singapore       None          SGP        NaN         NaN
# 4   049315  Singapore       None          SGP        NaN         NaN

# %%
# Transformo la latitus y longitud a formato geopoint para poder después visualizarlo en el mapa
data["geopoint"] = data.apply(lp.transformToGeoPoint, axis=1)

# %%
gdf = geopandas.GeoDataFrame(data, geometry=geopandas.points_from_xy(data.longitude, data.latitude))

# %%
# Elimino las columnas que no vamos a utilizar y reseteamos el índice

drop_cols = ['company_id','state_code', 'country_code','description','address1','address2','zip_code','city']
data = gdf.drop(drop_cols, axis =1)
data=data.dropna(subset=['longitude'])
data=data.dropna(subset=['latitude'])
data.reset_index
data.head(5)
# Out:
#            name   latitude   longitude  \
# 1         mig33  37.580304 -122.343679
# 6   Acme Mobile   1.278031  103.844350
# 7        InMobi   1.284082  103.851942
# 9      Fonemesh   1.289407  103.849962
# 10   Fotegrafik   1.352083  103.819836
#
#                                              geopoint  \
# 1   {'type': 'Point', 'coordinates': [-122.343679,...
# 6   {'type': 'Point', 'coordinates': [103.84435, 1...
# 7   {'type': 'Point', 'coordinates': [103.851942, ...
# 9   {'type': 'Point', 'coordinates': [103.849962, ...
# 10  {'type': 'Point', 'coordinates': [103.819836, ...
#
#                        geometry
# 1   POINT (-122.34368 37.58030)
# 6     POINT (103.84435 1.27803)
# 7     POINT (103.85194 1.28408)
# 9     POINT (103.84996 1.28941)
# 10    POINT (103.81984 1.35208)

# %%
#hacemos una primera visualización en el mapa

m = Map(location=[1.290270,103.851959],zoom_start=12)
for i, row in data.iterrows():
    Marker(
        location=row[["latitude","longitude"]],
        tooltip=row["name"],
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Aeropuerto

# %%
# Comprobamos que hay un aeropuerto en Singapur y sacamos sus coordenadas

req.geocode("Singapur International Airport")
# Out:
# {'type': 'Point', 'coordinates': [122.54365, 10.71379]}

# %%
def gplaces(query,radio):
    apiKey = os.getenv("GPLACES_APIKEY")
    lat = 1.298370
    long = 103.891290
    radius = {radio}
    tipo = {query}

    url = url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{long}&radius={radius}&type={tipo}&key=AIzaSyBr_5sdn9AKCx4Ptlwgbb7dIwojyiEOIdI"
    print(url)
    res = requests.get(url)
    data = res.json()
    return data

gplaces("school",2000)
result
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=1.29837,103.89129&radius={2000}&type={'school'}&key=AIzaSyBr_5sdn9AKCx4Ptlwgbb7dIwojyiEOIdI
# [{'_id': ObjectId('52cdef7c4bab8bd675297e8f'),
#   'name': 'Alstrasoft',
#   'category_code': 'software',
#   'founded_year': 1800,
#   'total_money_raised': '$0',
#   'offices': [{'description': None,
#     'address1': '14 Robinson Road #13-00 Far East Finance Buil',
#     'address2': 'Suite 100',
#     'zip_code': '048545',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297fda'),
#   'name': 'mig33',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$32.4M',
#   'offices': [{'description': 'mig33 Headquarters',
#     'address1': '111 North Bridge Road',
#     'address2': 'Peninsula Plaza #26-01',
#     'zip_code': '179098',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 37.580304,
#     'longitude': -122.343679}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675298060'),
#   'name': 'tyntec',
#   'category_code': 'mobile',
#   'founded_year': 2002,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'UK, London',
#     'address1': '6 St Andrew Street',
#     'address2': '',
#     'zip_code': 'EC4A 3AE',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'UK',
#     'address1': '11 Hope Street',
#     'address2': '',
#     'zip_code': 'IM1 1AQ',
#     'city': 'Douglas, Isle of Man',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Singapore',
#     'address1': '51 Goldhill Plaza',
#     'address2': '#11-01/02',
#     'zip_code': '308900',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Munich',
#     'address1': 'Hofmannstrasse 25-27',
#     'address2': '',
#     'zip_code': '81379',
#     'city': 'Munich',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Dortmund',
#     'address1': 'Semerteichstrasse 54-56',
#     'address2': '',
#     'zip_code': '44141',
#     'city': 'Dortmund',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'San Francisco',
#     'address1': '425 Market Street',
#     'address2': 'Suite 2200',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7911209,
#     'longitude': -122.398125}]},
#  {'_id': ObjectId('52cdef7c4bab8bd67529810e'),
#   'name': 'OANDA',
#   'category_code': 'web',
#   'founded_year': 1995,
#   'total_money_raised': '$117M',
#   'offices': [{'description': 'OANDA Canada',
#     'address1': '370 King Street West',
#     'address2': '2nd Floor, Box 60',
#     'zip_code': 'M5V 1J9',
#     'city': 'Toronto',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Asia Pacific',
#     'address1': '50 Collyer Quay',
#     'address2': '#04-03 OUE Bayfront',
#     'zip_code': '049321',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Corporation',
#     'address1': '140 Broadway',
#     'address2': '46th Floor',
#     'zip_code': '10005',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Sales',
#     'address1': '125 S. Wacker Drive',
#     'address2': 'Suite 300',
#     'zip_code': '60606',
#     'city': 'Chicago',
#     'state_code': 'IL',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Europe',
#     'address1': '1st Floor, 25 Watling Street',
#     'address2': '',
#     'zip_code': 'EC4M 9BR',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Europe Zurich',
#     'address1': 'Seefeldstrasse 223',
#     'address2': '',
#     'zip_code': '8008',
#     'city': 'Zurich',
#     'state_code': None,
#     'country_code': 'CHE',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'OANDA Japan Inc.',
#     'address1': '9F Tosei Building',
#     'address2': '1-18-12 Uchikanda',
#     'zip_code': '101-0047',
#     'city': 'Chiyoda-ku Tokyo',
#     'state_code': None,
#     'country_code': 'JPN',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7c4bab8bd67529815a'),
#   'name': 'Skyscanner',
#   'category_code': 'web',
#   'founded_year': 2001,
#   'total_money_raised': '£2.5M',
#   'offices': [{'description': 'Skyscanner Ltd',
#     'address1': 'The Stamp office',
#     'address2': '10 Waterloo Place',
#     'zip_code': 'EH1 3EG',
#     'city': 'Edinburgh',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Skyscanner Ltd',
#     'address1': '40 Princes street',
#     'address2': '',
#     'zip_code': 'EH2 2BY',
#     'city': 'Edinburgh',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Skyscanner Ltd',
#     'address1': '9-10 St Andrew Square',
#     'address2': '',
#     'zip_code': 'EH2 2AF',
#     'city': 'Edinburgh',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Skyscanner Ltd',
#     'address1': 'OFC Level 40',
#     'address2': '10 Collyer Quay',
#     'zip_code': '049315',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7c4bab8bd67529869f'),
#   'name': 'eYeka',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$9.34M',
#   'offices': [{'description': 'HQ',
#     'address1': '79 rue la Boétie',
#     'address2': '',
#     'zip_code': '75008',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.856667,
#     'longitude': 2.350987},
#    {'description': 'Asia-Pacific',
#     'address1': '24 Duxton Road',
#     'address2': '',
#     'zip_code': '089488',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7c4bab8bd67529877f'),
#   'name': 'Acme Mobile',
#   'category_code': 'mobile',
#   'founded_year': 2003,
#   'total_money_raised': '$0',
#   'offices': [{'description': None,
#     'address1': '50 B Tras Street',
#     'address2': '',
#     'zip_code': '078989',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.278031,
#     'longitude': 103.84435}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675298857'),
#   'name': 'InMobi',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '$216M',
#   'offices': [{'description': 'Bangalore',
#     'address1': 'Pebble Beach, Ground Floor, Embassy Golf Link Business Park,',
#     'address2': 'Off Intermediate Ring Road, Bangalore â€“ 560 071',
#     'zip_code': '',
#     'city': 'Bangalore',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'San Francisco',
#     'address1': '475 Brannan',
#     'address2': 'Suite 420',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4465496,
#     'longitude': -122.1709208},
#    {'description': 'Singapore',
#     'address1': 'UOB, Plaza 1, 36th Floor',
#     'address2': '80 Raffles Place',
#     'zip_code': '048624',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.284082,
#     'longitude': 103.851942},
#    {'description': 'London',
#     'address1': 'One Heddon Street',
#     'address2': '',
#     'zip_code': 'W1B 4BD',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Tokyo',
#     'address1': 'Fuji Building 7F 701-B',
#     'address2': 'Chiyoda-ku, Marunouchi',
#     'zip_code': '100-0005',
#     'city': 'Tokyo',
#     'state_code': None,
#     'country_code': 'JPN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Johannesburg',
#     'address1': 'Afria Palazzo Towers West,Corner of William',
#     'address2': 'Nicol & Montecasino Boulevard Fourways',
#     'zip_code': '',
#     'city': 'Johannesburg',
#     'state_code': None,
#     'country_code': 'ZAF',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Seoul',
#     'address1': '#3720, ASEM Building 159-1',
#     'address2': 'Samsung-Dong, Gangnam-Ku',
#     'zip_code': '',
#     'city': 'Seoul',
#     'state_code': None,
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Seoul',
#     'address1': '#3720, ASEM Building 159-1',
#     'address2': 'Samsung-Dong, Gangnam-Ku',
#     'zip_code': '',
#     'city': 'Seoul',
#     'state_code': None,
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675298878'),
#   'name': 'ReVou',
#   'category_code': 'software',
#   'founded_year': 2007,
#   'total_money_raised': '$0',
#   'offices': [{'description': None,
#     'address1': '14 Robinson Road #13-00',
#     'address2': 'Far East Finance Building',
#     'zip_code': '048545',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298a8a'),
#   'name': 'Fonemesh',
#   'category_code': 'mobile',
#   'founded_year': 2008,
#   'total_money_raised': '$250k',
#   'offices': [{'description': None,
#     'address1': '425 Market Street , Suite 2200',
#     'address2': '',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.791128,
#     'longitude': -122.398126},
#    {'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.289407,
#     'longitude': 103.849962}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298bff'),
#   'name': 'Fotegrafik',
#   'category_code': 'software',
#   'founded_year': 2007,
#   'total_money_raised': '$0',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.352083,
#     'longitude': 103.819836}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e1d'),
#   'name': 'Acronis',
#   'category_code': 'software',
#   'founded_year': 2002,
#   'total_money_raised': '$11M',
#   'offices': [{'description': 'NA Headquarters',
#     'address1': '23 3rd Avenue',
#     'address2': '',
#     'zip_code': '01803',
#     'city': 'Burlington',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.48774,
#     'longitude': -71.223868},
#    {'description': 'SFO',
#     'address1': '2200 Powell St.,',
#     'address2': 'Suite 100',
#     'zip_code': '94608',
#     'city': 'Emeryville',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.840054,
#     'longitude': -122.29166},
#    {'description': 'Asia Headquarters',
#     'address1': '120 Lower Delta Road',
#     'address2': '#05-15/16',
#     'zip_code': '169208',
#     'city': 'Cendex Centre',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd6752990df'),
#   'name': 'iDiscipulus',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': '-',
#     'address1': '6 Temasek Boulevard 29th Floor Suntec Tower Four',
#     'address2': '-',
#     'zip_code': '',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd67529913d'),
#   'name': 'Mobiquest',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '$0',
#   'offices': [{'description': '',
#     'address1': '10 Ubi Crescent',
#     'address2': '#07-41 Ubi Techpark',
#     'zip_code': '408564',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.326725,
#     'longitude': 103.894124}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675299413'),
#   'name': 'Garena',
#   'category_code': 'web',
#   'founded_year': 2009,
#   'total_money_raised': '$2M',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Taipei',
#     'state_code': None,
#     'country_code': 'TWN',
#     'latitude': None,
#     'longitude': None},
#    {'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Hanoi',
#     'state_code': None,
#     'country_code': 'VNM',
#     'latitude': None,
#     'longitude': None},
#    {'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Ho Chi Minh City',
#     'state_code': None,
#     'country_code': 'VNM',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675299493'),
#   'name': 'Pluit Solutions',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Headquarters',
#     'address1': '440, Ang Mo Kio Avenue 10 #11-1307',
#     'address2': '',
#     'zip_code': '560440',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.366447,
#     'longitude': 103.85415}]},
#  {'_id': ObjectId('52cdef7d4bab8bd6752994ff'),
#   'name': 'NetQoS',
#   'category_code': 'software',
#   'founded_year': 1999,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '5001 Plaza on the Lake',
#     'address2': '',
#     'zip_code': '78746',
#     'city': 'Austin',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 30.34819,
#     'longitude': -97.80058},
#    {'description': 'NetQoS EMEA',
#     'address1': '1650 Arlington Business Park',
#     'address2': '',
#     'zip_code': 'RG7 4SA',
#     'city': 'Theale Reading',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'NetQoS APAC',
#     'address1': 'Level 21, Centennial Tower 3 Temasek Ave.',
#     'address2': '',
#     'zip_code': '039190',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd67529962f'),
#   'name': 'Prosperity Financial Services Pte Ltd',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$370k',
#   'offices': [{'description': 'HQ',
#     'address1': '136B Telok Ayer Street',
#     'address2': '',
#     'zip_code': '068601',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.281506,
#     'longitude': 103.848023}]},
#  {'_id': ObjectId('52cdef7d4bab8bd6752997a3'),
#   'name': 'Jorbb',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Singapore',
#     'address1': '809 French Road',
#     'address2': '#06-162 Kitchener Complex',
#     'zip_code': '200809',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.308655,
#     'longitude': 103.861929}]},
#  {'_id': ObjectId('52cdef7d4bab8bd6752999b9'),
#   'name': 'Prosperity Financial Services Pte Ltd',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$370k',
#   'offices': [{'description': 'HQ',
#     'address1': '136B Telok Ayer Street',
#     'address2': '',
#     'zip_code': '068601',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.281506,
#     'longitude': 103.848023}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675299b2d'),
#   'name': 'Jorbb',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Singapore',
#     'address1': '809 French Road',
#     'address2': '#06-162 Kitchener Complex',
#     'zip_code': '200809',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.308655,
#     'longitude': 103.861929}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675299db1'),
#   'name': 'Ground labs',
#   'category_code': 'software',
#   'founded_year': None,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Global Head Quarters',
#     'address1': 'Ground Labs Pte Limited',
#     'address2': '#15-03 Suntec Tower Two, 9 Temasek Boulevard',
#     'zip_code': '038989',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'EMEA',
#     'address1': '2B, Station Parade',
#     'address2': '',
#     'zip_code': 'HP9 2PB',
#     'city': 'Beaconsfield',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7d4bab8bd67529a004'),
#   'name': 'SolArc',
#   'category_code': 'software',
#   'founded_year': 1991,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '9701 Richmond Ave',
#     'address2': 'Suite 250',
#     'zip_code': '77042',
#     'city': 'Houston',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 29.726962,
#     'longitude': -95.540876},
#    {'description': 'Tulsa Office',
#     'address1': '320 South Boston Avenue',
#     'address2': 'Suite 600',
#     'zip_code': '74103',
#     'city': 'Tulsa',
#     'state_code': 'OK',
#     'country_code': 'USA',
#     'latitude': 36.153262,
#     'longitude': -95.989909},
#    {'description': 'UK Office',
#     'address1': 'Clarendon House',
#     'address2': '52 Cornmarket Street',
#     'zip_code': '3HJ',
#     'city': 'Oxford OX1',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Singapore Office',
#     'address1': '391B Orchard Road',
#     'address2': '#23-01 Ngee Ann City Tower B',
#     'zip_code': '238874',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.303132,
#     'longitude': 103.835307}]},
#  {'_id': ObjectId('52cdef7d4bab8bd67529a16d'),
#   'name': 'Maven Lab',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Shop House Office',
#     'address1': '3B Stanley Street',
#     'address2': '',
#     'zip_code': '068722',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.279696,
#     'longitude': 103.847644}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a4b6'),
#   'name': 'Synthesio',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$2M',
#   'offices': [{'description': 'UK Office',
#     'address1': '50 Featherstone Street',
#     'address2': '',
#     'zip_code': 'EC1Y 8RT',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'US Office',
#     'address1': '116 West 23rd St',
#     'address2': '',
#     'zip_code': '10011',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7431836,
#     'longitude': -73.9935011},
#    {'description': 'French Office',
#     'address1': '8/10 rue Villedo',
#     'address2': '',
#     'zip_code': '75001',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Singapore Office',
#     'address1': '541 Orchard Road',
#     'address2': '',
#     'zip_code': '238881',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a612'),
#   'name': 'JobsTAXI',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '51A Neil Road',
#     'address2': '',
#     'zip_code': '088829',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.279684,
#     'longitude': 103.842646}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a753'),
#   'name': 'tenCube',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Headquarters',
#     'address1': '#01-06A, 31 Science Park Road',
#     'address2': 'The Crimson,',
#     'zip_code': '117611',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Regional Office',
#     'address1': '440 N, Wolfe Road,',
#     'address2': '',
#     'zip_code': '94085',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Regional Office',
#     'address1': 'B 121, Sector 5',
#     'address2': '',
#     'zip_code': '210301',
#     'city': 'NOIDA',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a754'),
#   'name': 'BAK2u',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Singapore HQ',
#     'address1': '135 Middle Road',
#     'address2': 'Bylands Building #02-08',
#     'zip_code': '188975',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.297079,
#     'longitude': 103.8557638}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a77a'),
#   'name': 'Veeam Software',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Americas Headquarters',
#     'address1': '8800 Lyra Drive',
#     'address2': 'Suite 350',
#     'zip_code': '43240',
#     'city': 'Columbus',
#     'state_code': 'OH',
#     'country_code': 'USA',
#     'latitude': 40.088052,
#     'longitude': -83.088566},
#    {'description': 'EMEA Headquarters',
#     'address1': '13/15 rue Jean Jaurès',
#     'address2': '',
#     'zip_code': '92800',
#     'city': 'Puteaux',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'APAC Headquarters',
#     'address1': 'Level 4, 22 Darley Rd',
#     'address2': 'PO Box 131 MANLY NSW 1655',
#     'zip_code': '2095',
#     'city': 'MANLY NSW',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Netherlands',
#     'address1': 'Evert van de Beekstraat 310',
#     'address2': '',
#     'zip_code': '1118 CX',
#     'city': 'Schiphol Centrum',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Germany',
#     'address1': 'Konrad-Zuse-Platz 8',
#     'address2': '',
#     'zip_code': '81829',
#     'city': 'München',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Россия',
#     'address1': 'Кондратьевский проспект, 15-3',
#     'address2': '',
#     'zip_code': '195197',
#     'city': 'Санкт-Петербург',
#     'state_code': None,
#     'country_code': 'RUS',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Poland',
#     'address1': 'Ul. Domaniewska 39A, Wejście A',
#     'address2': '',
#     'zip_code': '02-672',
#     'city': 'Warszawa',
#     'state_code': None,
#     'country_code': 'POL',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'India',
#     'address1': '#1356, 13th Flr, Platinum Tech Park',
#     'address2': '',
#     'zip_code': '400705',
#     'city': 'Navi Mumbai',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Italy',
#     'address1': 'Piazzale Biancamano 8',
#     'address2': '',
#     'zip_code': '20121',
#     'city': 'Milan',
#     'state_code': None,
#     'country_code': 'ITA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Turkey',
#     'address1': 'Buyukdere Caddesi Levent No:193 Binasi Kat:2',
#     'address2': '',
#     'zip_code': '34394',
#     'city': 'Levent Istanbul',
#     'state_code': None,
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'The United States',
#     'address1': '2520 Northwinds Parkway',
#     'address2': 'Suite 600',
#     'zip_code': '30009',
#     'city': 'Alpharetta',
#     'state_code': 'GA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'United Kingdom',
#     'address1': 'Hurst Grove',
#     'address2': '',
#     'zip_code': 'RG10 0SQ',
#     'city': 'Winnersh',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Israel',
#     'address1': 'P.O. 1129 Ramat Hasharon',
#     'address2': '',
#     'zip_code': '47247',
#     'city': '',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Canada',
#     'address1': '3773 Côte-Vertu Boulevard',
#     'address2': 'Suite 210',
#     'zip_code': '',
#     'city': 'Saint-Laurent',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nordics',
#     'address1': 'Frösundaviks Allé 15',
#     'address2': '',
#     'zip_code': '169 70',
#     'city': 'Solna',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Spain',
#     'address1': 'Calle de la Ribera del Loira, 46',
#     'address2': '',
#     'zip_code': '28042',
#     'city': 'Madrid',
#     'state_code': None,
#     'country_code': 'ESP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'South Africa',
#     'address1': '57 Sloane Street Cnr Main',
#     'address2': '',
#     'zip_code': '2021',
#     'city': 'Bryanston',
#     'state_code': None,
#     'country_code': 'ZAF',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Singapore',
#     'address1': '152 Beach Rd #04-08',
#     'address2': '',
#     'zip_code': '189721',
#     'city': 'Gateway East',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529a9bb'),
#   'name': 'mTelematics',
#   'category_code': 'mobile',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Headquarter, Singapore',
#     'address1': '3 Pemimpin Drive',
#     'address2': '#04-03',
#     'zip_code': '576147',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.3523202,
#     'longitude': 103.8422526}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529ad65'),
#   'name': 'Zopim',
#   'category_code': 'ecommerce',
#   'founded_year': 2008,
#   'total_money_raised': '$392k',
#   'offices': [{'description': '',
#     'address1': '8 Prince Georges Park',
#     'address2': 'Extension Block',
#     'zip_code': '118407',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.290801,
#     'longitude': 103.7807403}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529adab'),
#   'name': 'Nexway',
#   'category_code': 'ecommerce',
#   'founded_year': 2002,
#   'total_money_raised': '€14M',
#   'offices': [{'description': 'Nexway HQ',
#     'address1': '1 bd des Bouvets',
#     'address2': '',
#     'zip_code': '92741',
#     'city': 'Nanterre cedex',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.8980441,
#     'longitude': 2.2200007},
#    {'description': 'Nexway Services',
#     'address1': '1 bd Amiral Courbet',
#     'address2': 'CS 70002',
#     'zip_code': '30020',
#     'city': 'NÃ®mes cedex',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 43.837967,
#     'longitude': 4.3631044},
#    {'description': 'Nexway UK',
#     'address1': 'Unit 12, Westbourne Studios',
#     'address2': '242 Acklam Road',
#     'zip_code': 'W10 5JJ',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway Benelux',
#     'address1': "ChaussÃ©e d'Alsemberg",
#     'address2': '995 Bte 19',
#     'zip_code': '1180',
#     'city': 'Brussels',
#     'state_code': None,
#     'country_code': 'BEL',
#     'latitude': 50.7968479,
#     'longitude': 4.3358459},
#    {'description': 'Nexway Gmbh',
#     'address1': 'Hanauer Landstrasse 146',
#     'address2': '',
#     'zip_code': '60314',
#     'city': 'Frankfurt',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway Iberica',
#     'address1': 'C/ Duque de FernÃ¡n NÃºÃ±ez NÂº2 2Âº Oficina 2',
#     'address2': '',
#     'zip_code': '28012',
#     'city': 'Madrid',
#     'state_code': None,
#     'country_code': 'ESP',
#     'latitude': 40.4142986,
#     'longitude': -3.7033074},
#    {'description': 'Nexway Italy',
#     'address1': 'cVia Pascoli, 60',
#     'address2': '',
#     'zip_code': '20133',
#     'city': 'Milano',
#     'state_code': None,
#     'country_code': 'ITA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway / Boonty SEA',
#     'address1': '400 Orchard road',
#     'address2': '#09-05',
#     'zip_code': '238875',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.307505,
#     'longitude': 103.8295},
#    {'description': 'Degica / Boonty Japan',
#     'address1': 'TK Kichojijo Bldg 6F',
#     'address2': '2-5-10 Kichijoji Honcho, Musashino-shi',
#     'zip_code': '180-0004',
#     'city': 'Tokyo',
#     'state_code': None,
#     'country_code': 'JPN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway GmbH',
#     'address1': 'Haldenstrasse 1',
#     'address2': '',
#     'zip_code': '6340',
#     'city': 'Baar ZG',
#     'state_code': None,
#     'country_code': 'CHE',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway Portugal',
#     'address1': 'General Firmino Miguel, 3, Torre 2,1Â°A',
#     'address2': '',
#     'zip_code': '1600-100',
#     'city': 'Lisboa',
#     'state_code': None,
#     'country_code': 'PRT',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway Inc.',
#     'address1': '55 New Montgomery Street, Suite #518',
#     'address2': '',
#     'zip_code': '94105',
#     'city': 'San Fransisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Nexway Brazil',
#     'address1': 'Rua Maria Paula, NÂº36 2Âº Andar',
#     'address2': '',
#     'zip_code': '',
#     'city': 'SÃ¢o Paulo',
#     'state_code': None,
#     'country_code': 'BRA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b07c'),
#   'name': 'Majitek',
#   'category_code': 'software',
#   'founded_year': None,
#   'total_money_raised': '$7.5M',
#   'offices': [{'description': '',
#     'address1': 'SGX Centre 2,',
#     'address2': '4 Shenton Way #14-02',
#     'zip_code': '068807',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b23b'),
#   'name': 'TranZfinity',
#   'category_code': 'mobile',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'HQ',
#     'address1': '2177 Salk Ave',
#     'address2': 'Suite 165',
#     'zip_code': '92008',
#     'city': 'Carlsbad',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.137673,
#     'longitude': -117.277343},
#    {'description': 'Research & Development',
#     'address1': '900 E. Hamilton',
#     'address2': 'Suite 100',
#     'zip_code': '95008',
#     'city': 'Campbell',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.293067,
#     'longitude': -121.934606},
#    {'description': 'European HQ',
#     'address1': '1 Northumberland Avenue',
#     'address2': 'Trafalgar Square',
#     'zip_code': 'WC2N 5BW',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5069206,
#     'longitude': -0.1249337},
#    {'description': 'Asia HQ',
#     'address1': 'UOB Plaza 1',
#     'address2': '80 Raffles Place',
#     'zip_code': '048624',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b374'),
#   'name': 'GameSpot',
#   'category_code': 'games_video',
#   'founded_year': 1996,
#   'total_money_raised': '$0',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b417'),
#   'name': 'Aureliant',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$450k',
#   'offices': [{'description': 'Headquarters',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b4b8'),
#   'name': 'Transfer To',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$3M',
#   'offices': [{'description': 'Singapore',
#     'address1': '600 North Bridge Road',
#     'address2': 'Parkview Square #05-02',
#     'zip_code': '188778',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.3006925,
#     'longitude': 103.8575356},
#    {'description': 'United States',
#     'address1': '101 University Ave',
#     'address2': 'Suite 210',
#     'zip_code': '94301',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 40.705255,
#     'longitude': -74.010983}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b788'),
#   'name': 'BuzzCity',
#   'category_code': 'mobile',
#   'founded_year': 1999,
#   'total_money_raised': '$10M',
#   'offices': [{'description': 'Singapore Office',
#     'address1': 'No 1 Lorong 2, Toa Payoh,',
#     'address2': '#02-03, Yellow Pages Building,',
#     'zip_code': '319637',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b879'),
#   'name': 'eG Innovations',
#   'category_code': 'software',
#   'founded_year': 2001,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'eG Innovations, Inc.',
#     'address1': '33, Wood Ave, South',
#     'address2': 'Suite 600',
#     'zip_code': '08830',
#     'city': 'Iselin',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': 40.565015,
#     'longitude': -74.328206},
#    {'description': '33A Tanjong Pagar',
#     'address1': '',
#     'address2': '',
#     'zip_code': '088456',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.2791449,
#     'longitude': 103.8440888}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b8c6'),
#   'name': 'Brandtology',
#   'category_code': 'web',
#   'founded_year': None,
#   'total_money_raised': '$3.35M',
#   'offices': [{'description': 'Singapore (Intl HQ)',
#     'address1': '22 Changi South Avenue 2',
#     'address2': 'UPS House #02-05',
#     'zip_code': '486064',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'USA',
#     'address1': '3 Twin Dolphin Drive',
#     'address2': 'Suite 150, Redwood City',
#     'zip_code': '94065',
#     'city': 'CA',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'China - Shanghai',
#     'address1': 'Room 1801-1803, 18F, Westgate Tower,',
#     'address2': 'No.1038 Nanjing West Road,',
#     'zip_code': '200041',
#     'city': 'Shanghai',
#     'state_code': None,
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'HangZhou (North Asia HQ)',
#     'address1': 'Room 801,8th Floor,Building No.6 of Singapore-Hangzhou Science and Technology Park',
#     'address2': 'No.2 Science Park Rd',
#     'zip_code': '310018',
#     'city': None,
#     'state_code': None,
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Australia',
#     'address1': 'Level 31,ABN-AMRO Tower,',
#     'address2': '88 Phillip Street,',
#     'zip_code': 'NSW 2000',
#     'city': 'Sydney',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Malaysia',
#     'address1': "Suite E08-21, Block E,Plaza Mont' Kiara",
#     'address2': "No. 2, Jalan Kiara, Mont' Kiara",
#     'zip_code': '50480',
#     'city': 'Kuala Lumpur',
#     'state_code': None,
#     'country_code': 'MYS',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529bd7e'),
#   'name': 'YOOSE',
#   'category_code': 'mobile',
#   'founded_year': 2008,
#   'total_money_raised': '€25k',
#   'offices': [{'description': 'Germany',
#     'address1': 'Friedrichstrasse 171',
#     'address2': '',
#     'zip_code': '10117',
#     'city': 'Berlin',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': 52.5145532,
#     'longitude': 13.3892132},
#    {'description': 'Singapore',
#     'address1': '25 Duxton Road',
#     'address2': '',
#     'zip_code': '089489',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c14a'),
#   'name': 'Peekspy',
#   'category_code': 'web',
#   'founded_year': 2008,
#   'total_money_raised': '$0',
#   'offices': [{'description': 'Peekspy pte. ltd.',
#     'address1': 'Blk 970 Toa Payoh North',
#     'address2': '#02-12/15 Toa Payoh Industrial Building',
#     'zip_code': '318992',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 1.3427648,
#     'longitude': 103.8510535}]}]

# %% [markdown]
# ### Conectamos con la API de Foursquare

# %%
def requestFoursquare(query,data,radio=1000):
    client_idd = os.getenv("4S_CLIENT_ID")
    client_secret=os.getenv("CLIENT_SECRET")
    
    long = data['longitude']
    lat = data['latitude']

    params = {"client_id": client_idd,
              "client_secret":client_secret,
              "v": "20180323",
              "ll":f'{lat},{long}',
              "radius":f'{radio}',
              "query":f'{query}', 
              "limit":20 }

    url = f"https://api.foursquare.com/v2/venues/explore"
    
    resp = requests.get(url=url, params=params)
    res = json.loads(resp.text)

    return res["response"]["totalResults"]
requestFoursquare("coffe",data,1000)
# Out:
# {'meta': {'code': 429,
#   'errorType': 'quota_exceeded',
#   'errorDetail': 'Quota exceeded',
#   'requestId': '5efae0f130926a6e9788fbbb'},
#  'response': {}}

# %%
total = 87
offices_w=87/total
school_w=26/total
party_w=50/total
starbucks_w=9/total
vegan_w=1/total
dog=1/total

vegan="4bf58dd8d48988d1d3941735"
nightlife="4d4b7105d754a06376d81259"
tech_startup="4bf58dd8d48988d125941735"

# %%
# Buscamos por cada empresa cuantos sitios de los preferidos hay cerca
# Ponderamos por el número de gente y la importancia

data["Offices near"] = data.apply(lambda row: (requestFoursquare(tech_startup,row,2000)*2*offices_w), axis=1)
data["Rest"] = data.apply(lambda row: (requestFoursquare("restaurant",row,1000)*2), axis=1)
data["School"] = data.apply(lambda row: (requestFoursquare("school",row,1200)*2*school_w), axis=1)

# %%
data["Starbucks"] = data.apply(lambda row: (requestFoursquare("starbucks",row,200)*starbucks_w), axis=1)
data["Night club"] = data.apply(lambda row: (requestFoursquare("nightlife",row,500)*party_w), axis=1)

# %%
data["Dog care"] = data.apply(lambda row: (requestFoursquare("dog care",row,2000)*0.5*dog), axis=1)
data["Vegan"] = data.apply(lambda row: (requestFoursquare(vegan,row,1000)*0.5*vegan_w), axis=1)

# %%
# Sumamos los puntos totales y ordenamos 

data["Total Points"] = data["Offices near"]+data['Rest']+data['School']+data['Night club']+data['Starbucks']+data['Dog care']+data["Vegan"]

#Renombramos el dataframe y nos quedamos unicamente con las puntuaciones
total_points=data
total_points["Total Points"].apply(np.floor)
total_points.sort_values(by="Total Points", ascending=False)
total_points

drop_cols = ['latitude','longitude', 'geopoint','geometry']
total_points = total_points.drop(drop_cols, axis =1)
total_points.round({"School":1, "Starbucks":1, "Night club":1, "Dog care":1,"Vegan":1,"Total Points":1 })

# %%
# Visualizamos la empresa con más puntos

total_points.sort_values(by="Total Points").head(1)

# %% [markdown]
# ### Visualizción mapas

# %%
def mapa(coord):

    m = Map(location=coord,zoom_start=12)
    for i, row in data.iterrows():
        Marker(
            location=row[["latitude","longitude"]],
            tooltip=row["name"],
        ).add_to(m)
    return m

coordenates_sg=[1.290270,103.851959]
mapa(coordenates_sg)

# %%
apiKey = os.getenv('GPLACES_APIKEY')
x

# %%
#Restaurantes
places=req.gPlaces(1.298370,103.891290,"restaurant",1000)
results_rx=[(places[i]["name"], places[i]["geometry"]["location"]["lat"], places[i]["geometry"]["location"]["lng"]) for i in range(len(places))]
results_rx=pd.DataFrame(results_map, columns=['name', 'latitude', 'longitude'])
results_map.to_json("output/restaurants.json",orient="records")

# %%
#Colegios

places=req.gPlaces(1.298370,103.891290,"school",1000)
results_sch=[(places[i]["name"], places[i]["geometry"]["location"]["lat"], places[i]["geometry"]["location"]["lng"]) for i in range(len(places))]
results_sch=pd.DataFrame(results_map, columns=['name', 'latitude', 'longitude'])
results_map.to_json("output/schools.json",orient="records")

# %%
#Clubs

places=req.gPlaces(1.298370,103.891290,"night clubs",1000)
results_sch=[(places[i]["name"], places[i]["geometry"]["location"]["lat"], places[i]["geometry"]["location"]["lng"]) for i in range(len(places))]
results_sch=pd.DataFrame(results_map, columns=['name', 'latitude', 'longitude'])
results_map.to_json("output/night_clubs.json",orient="records")

# %%
#Starbucks

places=req.gPlaces(1.298370,103.891290,"starbucks",500)
results_sch=[(places[i]["name"], places[i]["geometry"]["location"]["lat"], places[i]["geometry"]["location"]["lng"]) for i in range(len(places))]
results_sch=pd.DataFrame(results_map, columns=['name', 'latitude', 'longitude'])
results_map.to_json("output/starbucks.json",orient="records")

# %%
data.sort_values(by="Total Points", ascending=False)


# Sacamos una tabla con los valores finales
drop_cols = ['latitude','longitude', 'geopoint','geometry']
data = gdf.drop(drop_cols, axis =1)
data

# %%
geocode("Singapur")
